# %%
import requests
import pandas as pd

# %%
API_KEY = "your_key"

# %%
url = "https://financialmodelingprep.com/stable/historical-price-eod/full"

params = {
    "symbol": "AAPL",
    "apikey": API_KEY
}

response = requests.get(url, params=params)

stock_data = response.json()

stock_df = pd.DataFrame(stock_data)

stock_df.head()
# Out:
#   symbol        date    open    high     low   close    volume  change  \
# 0   AAPL  2026-08-21  312.05  312.38  307.01  309.35  46876815   -2.70
# 1   AAPL  2026-08-20  317.46  320.28  310.65  311.30  40959200   -6.15
# 2   AAPL  2026-08-19  310.14  319.28  309.60  316.83  50505646    6.69
# 3   AAPL  2026-08-18  307.58  311.49  305.74  310.03  53424535    2.45
# 4   AAPL  2026-08-17  306.21  307.66  302.94  305.59  38169300   -0.62
#
#    changePercent      vwap
# 0       -0.86525  310.1975
# 1       -1.94000  314.9225
# 2        2.16000  313.9625
# 3        0.79654  308.7100
# 4       -0.20248  305.6000

# %%
stock_df.to_csv("apple_stock_data.csv", index=False)

# %%
url = "https://financialmodelingprep.com/stable/earnings"

params = {
    "symbol": "AAPL",
    "apikey": API_KEY
}

response = requests.get(url, params=params)

earnings_data = response.json()

earnings_df = pd.DataFrame(earnings_data)

earnings_df.head()
# Out:
#   symbol        date  epsActual  epsEstimated  revenueActual  \
# 0   AAPL  2026-10-29        NaN          1.98            NaN
# 1   AAPL  2026-07-30       2.02          1.89   1.094170e+11
# 2   AAPL  2026-04-30       2.01          1.95   1.111840e+11
# 3   AAPL  2026-01-29       2.85          2.67   1.437560e+11
# 4   AAPL  2025-10-30       1.85          1.73   1.024660e+11
#
#    revenueEstimated lastUpdated
# 0      1.132052e+11  2026-08-24
# 1      1.090389e+11  2026-08-24
# 2      1.094576e+11  2026-07-29
# 3      1.383910e+11  2026-06-04
# 4      1.022271e+11  2026-06-04

# %%
earnings_df.to_csv("apple_earnings_data.csv", index=False)

# %%
print(stock_df.columns)
print(earnings_df.columns)
# Out:
# Index(['symbol', 'date', 'open', 'high', 'low', 'close', 'volume', 'change',
#        'changePercent', 'vwap'],
#       dtype='str')
# Index(['symbol', 'date', 'epsActual', 'epsEstimated', 'revenueActual',
#        'revenueEstimated', 'lastUpdated'],
#       dtype='str')

# %%
stock_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   symbol         1253 non-null   str
#  1   date           1253 non-null   datetime64[us]
#  2   open           1253 non-null   float64
#  3   high           1253 non-null   float64
#  4   low            1253 non-null   float64
#  5   close          1253 non-null   float64
#  6   volume         1253 non-null   int64
#  7   change         1253 non-null   float64
#  8   changePercent  1253 non-null   float64
#  9   vwap           1253 non-null   float64
# dtypes: datetime64[us](1), float64(7), int64(1), str(1)
# memory usage: 102.9 KB

# %%
stock_df.isnull().sum()
# Out:
# symbol           0
# date             0
# open             0
# high             0
# low              0
# close            0
# volume           0
# change           0
# changePercent    0
# vwap             0
# dtype: int64

# %%
stock_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
stock_df.describe()
# Out:
#                              date         open         high          low  \
# count                        1253  1253.000000  1253.000000  1253.000000
# mean   2024-02-21 14:23:04.836392   200.571780   202.791844   198.583911
# min           2021-08-25 00:00:00   126.010000   127.770000   124.170000
# 25%           2022-11-21 00:00:00   163.920000   165.820000   162.000000
# 50%           2024-02-22 00:00:00   189.160000   190.380000   187.480000
# 75%           2025-05-22 00:00:00   231.600000   233.800000   229.350000
# max           2026-08-21 00:00:00   340.030000   344.570000   337.350000
# std                           NaN    47.497054    47.942930    47.123884
#
#              close        volume       change  changePercent         vwap
# count  1253.000000  1.253000e+03  1253.000000    1253.000000  1253.000000
# mean    200.785571  6.446454e+07     0.214395       0.116637   200.683276
# min     125.020000  1.791060e+07   -14.280000      -7.650000   126.170000
# ...

# %%
stock_df["date"].duplicated().sum()
# Out:
# np.int64(0)

# %%
(stock_df["high"] < stock_df[["open", "close"]].max(axis=1)).sum()
# Out:
# np.int64(0)

# %%
(stock_df["low"] > stock_df[["open", "close"]].min(axis=1)).sum()
# Out:
# np.int64(0)

# %%
earnings_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symbol            165 non-null    str
#  1   date              165 non-null    datetime64[us]
#  2   epsActual         164 non-null    float64
#  3   epsEstimated      111 non-null    float64
#  4   revenueActual     164 non-null    float64
#  5   revenueEstimated  117 non-null    float64
#  6   lastUpdated       165 non-null    str
# dtypes: datetime64[us](1), float64(4), str(2)
# memory usage: 11.4 KB

# %%
earnings_df.isnull().sum()
# Out:
# symbol               0
# date                 0
# epsActual            1
# epsEstimated        54
# revenueActual        1
# revenueEstimated    48
# lastUpdated          0
# dtype: int64

# %%
earnings_df[earnings_df["epsActual"].isna()]
# Out:
#   symbol       date  epsActual  epsEstimated  revenueActual  revenueEstimated  \
# 0   AAPL 2026-10-29        NaN          1.98            NaN      1.132052e+11
#
#   lastUpdated
# 0  2026-08-24

# %%
earnings_df[earnings_df["revenueActual"].isna()]
# Out:
#   symbol       date  epsActual  epsEstimated  revenueActual  revenueEstimated  \
# 0   AAPL 2026-10-29        NaN          1.98            NaN      1.132052e+11
#
#   lastUpdated
# 0  2026-08-24

# %%
earnings_df[earnings_df["epsEstimated"].isna()].head(10)
# Out:
#     symbol       date  epsActual  epsEstimated  revenueActual  \
# 92    AAPL 2003-12-19     0.0022           NaN   1.715000e+09
# 93    AAPL 2003-10-15     0.0009           NaN   1.545000e+09
# 94    AAPL 2003-04-16     0.0007           NaN   1.475000e+09
# 95    AAPL 2003-01-15    -0.0004           NaN   1.472000e+09
# 96    AAPL 2002-12-19    -0.0022           NaN   1.443000e+09
# 98    AAPL 2002-05-14     0.0020           NaN   1.495000e+09
# 100   AAPL 2001-12-21     0.0034           NaN   1.450000e+09
# 101   AAPL 2001-08-13     0.0031           NaN   1.475000e+09
# 102   AAPL 2001-04-18     0.0022           NaN   1.431000e+09
# 103   AAPL 2001-02-12    -0.0104           NaN   1.007000e+09
#
#      revenueEstimated lastUpdated
# 92       2.006000e+09  2026-06-04
# 93                NaN  2026-06-04
# 94                NaN  2026-06-04
# 95                NaN  2026-06-04
# 96                NaN  2026-06-04
# 98       1.429000e+09  2026-06-04
# 100      1.375000e+09  2026-06-04
# ...

# %%
earnings_df[earnings_df["revenueEstimated"].isna()].head(10)
# Out:
#     symbol       date  epsActual  epsEstimated  revenueActual  \
# 93    AAPL 2003-10-15     0.0009           NaN   1.545000e+09
# 94    AAPL 2003-04-16     0.0007           NaN   1.475000e+09
# 95    AAPL 2003-01-15    -0.0004           NaN   1.472000e+09
# 96    AAPL 2002-12-19    -0.0022           NaN   1.443000e+09
# 101   AAPL 2001-08-13     0.0031           NaN   1.475000e+09
# 102   AAPL 2001-04-18     0.0022           NaN   1.431000e+09
# 103   AAPL 2001-02-12    -0.0104           NaN   1.007000e+09
# 104   AAPL 2000-10-18     0.0093           NaN   1.870000e+09
# 107   AAPL 2000-01-19     0.0101        0.0075   2.343000e+09
# 108   AAPL 1999-12-22     0.0061           NaN   1.336000e+09
#
#      revenueEstimated lastUpdated
# 93                NaN  2026-06-04
# 94                NaN  2026-06-04
# 95                NaN  2026-06-04
# 96                NaN  2026-06-04
# 101               NaN  2026-06-04
# 102               NaN  2026-06-04
# 103               NaN  2026-06-04
# ...

# %%
earnings_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
earnings_df.describe()
# Out:
#                              date   epsActual  epsEstimated  revenueActual  \
# count                         165  164.000000    111.000000   1.640000e+02
# mean   2006-04-25 15:07:38.181818    0.377632      0.537207   2.886232e+10
# min           1985-09-30 00:00:00   -0.050400     -0.012500   4.089000e+08
# 25%           1996-01-17 00:00:00    0.005035      0.020000   1.592775e+09
# 50%           2006-04-19 00:00:00    0.020000      0.320000   4.364500e+09
# 75%           2016-07-26 00:00:00    0.520000      0.810000   5.298825e+10
# max           2026-10-29 00:00:00    2.850000      2.670000   1.437560e+11
# std                           NaN    0.607184      0.646613   3.720073e+10
#
#        revenueEstimated
# count      1.170000e+02
# mean       3.953777e+10
# min        1.280800e+09
# 25%        2.879250e+09
# 50%        3.393073e+10
# 75%        6.380240e+10
# max        1.383910e+11
# std        3.887201e+10

# %%
earnings_df["date"].duplicated().sum()
# Out:
# np.int64(0)

# %%
# !pip install psycopg2-binary sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from sqlalchemy import create_engine
#connect to pastgreSQL
username = "postgres"
password = "123456"
host = "localhost"
post = "5432"
database = "FMP"
engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{post}/{database}")

#load dataframe into postgresql
table_name = "stock_data"
stock_df.to_sql(table_name, engine, if_exists="replace", index=False)
print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'stock_data' in database 'FMP'.

# %%
from sqlalchemy import create_engine
#connect to pastgreSQL
username = "postgres"
password = "123456"
host = "localhost"
post = "5432"
database = "FMP"
engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{post}/{database}")

table_name = "earnings_data"
earnings_df.to_sql(
    table_name,
    engine,
    if_exists="replace",
    index=False
)

print(f"Data successfully loaded into table '{table_name}'.")
# Out:
# Data successfully loaded into table 'earnings_data'.
